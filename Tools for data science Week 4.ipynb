# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Gustavo Dias Cardoso</b> <br>
# Desired occupation: Data Scientist

# %% [markdown]
# <i>I'm interested in data science because data is one of the most valuable assets of any company. Therefore, understanding data is crucial to the decision making process.</i>

# %% [markdown]
# ### This code returns the factorial of 5

# %%
import math
fac5 = math.factorial(5)
print("5! = "+str(fac5))
# Out:
# 5! = 120

# %% [markdown]
# ---
#
# <ol>
# <li>List 1</li>
# <li>List 2</li>
# <li>List 3</li>
# </ol>
#
# >Blocked Quote
#
# <a href="https://www.coursera.org/" >Link to Coursera</a>
